# %%
import random
def select_col():
    colours=["r","b","o","y","p","g","w"]
    c1=random.choice(colours)
    c2=random.choice(colours)
    c3=random.choice(colours)
    c4=random.choice(colours)
    data=(c1,c2,c3,c4)
    return(data)
def tryit(c1,c2,c3,c4):
    print("the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite")
    try_again=True
    while try_again==True:
        u1=input("enter your choice for place 1: ")
        u1=u1.lower()
        if u1!="r" and u1!="b" and u1!="o" and u1!="y" and u1!="p" and u1!="g" and u1!="w" :
            print("incorrect selection")
        else:
            try_again=False
    try_again=True
    while try_again==True:
        u2=input("enter your choice for place 2: ")
        u2=u2.lower()
        if u2!="r" and u2!="b" and u2!="o" and u2!="y" and u2!="p" and u2!="g" and u2!="w" :
            print("incorrect selection")
        else:
            try_again=False
    try_again=True
    while try_again==True:
        u3=input("enter your choice for place 3: ")
        u3=u3.lower()
        if u3!="r" and u3!="b" and u3!="o" and u3!="y" and u3!="p" and u3!="g" and u3!="w" :
            print("incorrect selection")
        else:
            try_again=False
    try_again=True
    while try_again==True:
        u4=input("enter your choice for place 4: ")
        u4=u4.lower()
        if u4!="r" and u4!="b" and u4!="o" and u4!="y" and u4!="p" and u4!="g" and u4!="w" :
            print("incorrect selection")
        else:
            try_again=False
    correct=0
    wrong_place=0
    if c1==u1:
        correct=correct+1
    elif c1==u2 or c1==u3 or c1==u4:
        wrong_place=wrong_place+1
    if c2==u2:
        correct=correct+1
    elif c2==u1 or c2==u3 or c2==u4:
        wrong_place=wrong_place+1
    if c3==u3:
        correct=correct+1
    elif c3==u2 or c3==u1 or c3==u4:
        wrong_place=wrong_place+1
    if c4==u4:
        correct=correct+1
    elif c4==u2 or c4==u1 or c4==u1:
        wrong_place=wrong_place+1
    print("correct colour in correct place:", correct)
    print("correct colour but in wrong place:" , wrong_place)
    print()
    data2=[correct,wrong_place]
    return data2
def main():
    (c1,c2,c3,c4)=select_col()
    score=0
    play=True
    while play==True:
        (correct,wrong_place)=tryit(c1,c2,c3,c4)
        score=score+1
        if correct==4:
            play=False
    print("you win")
    print("you took", score, "guesses")
main()
# Out:
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: b
# enter your choice for place 2: y
# enter your choice for place 3: p
# enter your choice for place 4: g
# correct colour in correct place: 1
# correct colour but in wrong place: 2
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: b
# enter your choice for place 2: o
# enter your choice for place 3: y
# enter your choice for place 4: w
# correct colour in correct place: 0
# correct colour but in wrong place: 2
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: b
# enter your choice for place 2: y
# enter your choice for place 3: r
# enter your choice for place 4: p
# correct colour in correct place: 2
# correct colour but in wrong place: 1
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: b
# enter your choice for place 2: y
# enter your choice for place 3: w
# enter your choice for place 4: p
# correct colour in correct place: 1
# correct colour but in wrong place: 1
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: b
# enter your choice for place 2: p
# enter your choice for place 3: r
# enter your choice for place 4: y
# correct colour in correct place: 1
# correct colour but in wrong place: 2
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: b
# enter your choice for place 2: w
# enter your choice for place 3: r
# enter your choice for place 4: p
# correct colour in correct place: 1
# correct colour but in wrong place: 1
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: w
# enter your choice for place 2: y
# enter your choice for place 3: r
# enter your choice for place 4: p
# correct colour in correct place: 2
# correct colour but in wrong place: 0
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: o
# enter your choice for place 2: y
# enter your choice for place 3: r
# enter your choice for place 4: w
# correct colour in correct place: 2
# correct colour but in wrong place: 0
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: p
# enter your choice for place 2: y
# enter your choice for place 3: r
# enter your choice for place 4: g
# correct colour in correct place: 2
# correct colour but in wrong place: 1
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: g
# enter your choice for place 2: y
# enter your choice for place 3: r
# enter your choice for place 4: p
# correct colour in correct place: 3
# correct colour but in wrong place: 0
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: r
# enter your choice for place 2: y
# enter your choice for place 3: r
# enter your choice for place 4: p
# correct colour in correct place: 2
# correct colour but in wrong place: 0
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: b
# enter your choice for place 2: y
# enter your choice for place 3: r
# enter your choice for place 4: p
# correct colour in correct place: 2
# correct colour but in wrong place: 1
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: g
# enter your choice for place 2: y
# enter your choice for place 3: r
# enter your choice for place 4: p
# correct colour in correct place: 3
# correct colour but in wrong place: 0
#
# the colours are: (r)ed, (b)lue , (o)range, (y)ellow, (p)ink, (g)reen, (w)hite
# enter your choice for place 1: g
# enter your choice for place 2: y
# enter your choice for place 3: r
# enter your choice for place 4: b
# correct colour in correct place: 4
# correct colour but in wrong place: 0
#
# you win
# you took 14 guesses
